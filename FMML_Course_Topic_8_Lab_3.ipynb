# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh63055/fmml-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 05:03:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  91.9MB/s    in 0.8s
#
# 2024-03-28 05:03:29 (91.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7207   1711.01131v2  Sparse variational approximations allow for pr...  stat
# 11322  1509.05113v2  We consider the problem of learning the prefer...  stat
# 7313   1711.09159v1  The notion of disentangled autoencoders was pr...  stat
# 28668  1707.04677v1  This paper aims at task-oriented action predic...    cs
# 36465   1401.5852v1  We present algorithms for generating alternati...    cs
# ...             ...                                                ...   ...
# 10718   1302.2672v1  We study the problem of online learning with a...  stat
# 9565   1709.07581v1  Automatic mesh-based shape generation is of gr...    cs
# 1992   1711.06431v2  We present a method for explaining the image c...    cs
# 37891   1103.1761v3  Inference in popular nonparametric Bayesian mo...  stat
# 11913  1704.00708v1  In this paper we develop a new framework that ...    cs
#
#                                                    title  year  \
# 7207   Structured Variational Inference for Coupled G...  2017
# 11322  Revealed Preference at Scale: Learning Persona...  2015
# 7313   Quantifying the Effects of Enforcing Disentang...  2017
# 28668  Knowledge-Guided Recurrent Neural Network Lear...  2017
# 36465  Algorithms for Generating Ordered Solutions fo...  2014
# ...                                                  ...   ...
# 10718                          Competing With Strategies  2013
# 9565   Hierarchical Detail Enhancing Mesh-Based Shape...  2017
# 1992   Using KL-divergence to focus Deep Visual Expla...  2017
# 37891  A Kernel Approach to Tractable Bayesian Nonpar...  2011
# 11913  No Spurious Local Minima in Nonconvex Low Rank...  2017
#
#                                                 keywords
# 7207   [variational, approximations, principled, infe...
# 11322  [preferences, heterogeneous, population, obser...
# 7313   [disentangled, autoencoders, extension, variat...
# 28668  [prediction, predicting, accomplishing, challe...
# 36465  [algorithms, generating, alternative, solution...
# ...                                                  ...
# 10718  [strategies, analyzing, minimization, algorith...
# 9565   [automatic, generation, disciplines, industria...
# 1992   [explaining, classification, predictions, conv...
# 37891  [inference, nonparametric, typically, approxim...
# 11913  [framework, landscape, underlying, including, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7207     [variational, approximations, principled, infe...
# 11322    [preferences, heterogeneous, population, obser...
# 7313     [disentangled, autoencoders, extension, variat...
# 28668    [prediction, predicting, accomplishing, challe...
# 36465    [algorithms, generating, alternative, solution...
#                                ...
# 23077    [combining, probabilistic, graphical, promisin...
# 6435     [clustering, probabilistic, framework, databas...
# 22798    [introduced, phalanxes, detection, classificat...
# 21166    [cognitive, framework, introduce, cognitive, c...
# 6909     [different, inference, approaches, factorisati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8793 words.
# Out of those 4534 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="19e9c08d-a7c6-460c-a9d2-f7c012e29f3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19e9c08d-a7c6-460c-a9d2-f7c012e29f3d")) {                    Plotly.newPlot(                        "19e9c08d-a7c6-460c-a9d2-f7c012e29f3d",                        [{"x":["computational","approximate","uncertainty","inference","parameterization","regression","generative","approximations","complexity","applications","algorithm","posteriori","interested","predictive","posterior","processes","posteriors","variables","principled","structured","variational","dependencies","capturing","structure","heterogeneous","preference","parametric","parameters","combinations","dimension","empirically","observing","potential","consisting","preferences","customers","population","customization","observation","structural","likelihood","underlying","personalized","dimensional","specialized","assortment","offerings","regularized","estimator","observations","assumptions","introducing","representations","existence","literature","parameter","available","establish","autoencoder","disentanglement","extension","interpretable","autoencoders","consistent","consequences","independent","controlling","disentangled","quantifying","performance","enforcing","behaviour","discriminative","predictable","experiments","effectively","generated","represents","sequences","annotated","decomposition","facilitate","challenges","description","recurrently","accomplishing","predicting","hierarchically","recurrent","knowledge","containing","alleviate","according","integrate","prediction","representation","extensively","specified","procedure","effectiveness","auxiliary","introduce","secondary","structures","algorithms","technique","reconstructed","composition","alternative","duplicate","construction","generating","frameworks","decreasing","synthetic","solutions","including","multiplication","experimental","representing","techniques","approaches","particular","information","preserving","distilled","principles","remarkable","protection","qualitative","corresponding","summarizing","difficult","defending","incorporates","estimates","difference","defensive","percentage","quantitative","pertaining","possession","strategies","advantage","trajectory","understanding","reinforcement","comprehensive","identified","framework","observational","combining","unfamiliar","statistician","imputation","estimation","causality","judiciously","estimating","statisticians","estimated","demonstrated","generalized","challenging","incomplete","nonlinear","beginning","debugging","shrinking","elimination","inability","automated","different","implementations","development","outperform","convolutions","exploitation","convolutional","historical","architecture","conditional","processing","autoregressive","correlation","multivariate","forecasting","thermodynamic","presented","quantities","interesting","extensive","throughout","annealing","distribution","stochastic","practically","functions","integrals","simulation"],"y":[282,93,89,195,10,105,111,31,226,431,827,11,24,65,33,88,1,133,13,106,51,52,37,336,28,24,31,248,34,69,72,12,154,39,44,15,52,3,55,70,67,123,17,183,18,0,2,43,32,71,67,56,223,34,131,126,297,50,22,0,93,33,21,83,10,131,23,6,19,885,9,32,97,2,628,113,181,45,83,62,53,49,116,84,2,2,69,8,140,357,51,20,105,47,211,337,31,35,124,186,19,332,8,139,601,259,29,23,104,3,63,84,31,13,121,157,231,13,378,71,356,425,282,725,50,4,26,26,3,57,110,7,137,2,36,72,69,5,11,71,5,2,111,101,19,157,128,57,40,553,8,93,2,0,3,206,14,0,68,0,58,79,85,253,30,59,10,4,4,14,4,96,750,26,151,85,19,20,392,22,227,102,269,7,78,20,19,0,180,12,70,166,22,9,186,139,16,214,0,69],"type":"bar"},{"x":["computational","approximate","uncertainty","inference","param ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4534,), (4534, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Importance</span> <span style=''>Sampling</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Influence</span> <span style=''>Based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>Strategy</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Importance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>main</span> <span style=''>problems</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.378323108384458);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>function</span> <span style=''>which</span> <span style=''>should</span> <span style=''>ideally</span> <span style=''>be</span> <span style=''>as</span> <span style=''>close</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6716417910447762);'>posterior</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.35191637630662015);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Typically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represent</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>function</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3134328358208955);'>factorization</span> <span style=''>ie</span> <span style=''>product</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>tables</span> <span style=''>(CPTs)</span> <span style=''>Given</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>diagnostic</span> <span style=''>evidence</span> <span style=''>we</span> <span style=''>do</span> <span style=''>not</span> <span style=''>have</span> <span style=''>explicit</span> <span style=''>forms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>CPTs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>first</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>form</span> <span style=''>for</span> <span style=''>the</span> <span style=''>CPTs</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>function</span> <span style=''>Since</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calculation</span> <span style=''>is</span> <span style=''>hard</span> <span style=''>we</span> <span style=''>usually</span> <span style=''>only</span> <span style=''>use</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.456140350877193);'>approximations</span> <span style=''>We</span> <span style=''>review</span> <span style=''>several</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3058823529411765);'>strategies</span> <span style=''>and</span> <span style=''>point</span> <span style=''>out</span> <span style=''>their</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style=''>Two</span> <span style=''>Sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypothesis</span> <span style=''>Testing</span> <span style=''>Using</span> <span style=''>Kernel</span> <span style=''>Set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style=''>The</span> <span style=''>two</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>studied</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>scenario</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>small</span> <span style=''>sample</span> <span style=''>sizes</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>two</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>posed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>one</span> <span style=''>class</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>the</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>that</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style=''>common</span> <span style=''>class</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>average</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>error</span> <span style=''>given</span> <span style=''>a</span> <span style=''>set</span> <span style=''>is</span> <span style=''>less</span> <span style=''>than</span> <span style=''>or</span> <span style=''>equal</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Bayes</span> <span style=''>error</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decreases</span> <span style=''>as</span> <span style=''>a</span> <span style=''>power</span> <span style=''>of</span> <span style=''>n</span> <span style=''>number</span> <span style=''>of</span> <span style=''>sample</span> <span style=''>data</span> <span style=''>points</span> <span style=''>in</span> <span style=''>the</span> <span style=''>set</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>Set</span> <span style=''>Kernel</span> <span style=''>for</span> <span style=''>directly</span> <span style=''>mapping</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>data</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Rapid</span> <span style=''>Mixing</span> <span style=''>Swendsen</span> <span style=''>Wang</span> <span style=''>Sampler</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3101736972704715);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Partitioned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attractive</span> <span style=''>Models</span> <br/><br/><span style=''>The</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>popular</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>used</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.33447098976109224);'>inference</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <span style=''>(GMs)</span> <span style=''>These</span> <span style=''>tasks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intractable</span> <span style=''>in</span> <span style=''>general</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>often</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>slow</span> <span style=''>mixing</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>Swendsen</span> <span style=''>Wang</span> <span style=''>dynamics</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3500000000000001);'>sophisticated</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>overcome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottlenecks</span> <span style=''>that</span> <span style=''>impede</span> <span style=''>the</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>O(log</span> <span style=''>n)</span> <span style=''>mixing</span> <span style=''>time</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attractive</span> <span style=''>binary</span> <span style=''>pairwise</span> <span style=''>GMs</span> <span style=''>(ie</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>ferromagnetic</span> <span style=''>Ising</span> <span style=''>models)</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3101736972704715);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitioned</span> <span style=''>graphs</span> <span style=''>having</span> <span style=''>n</span> <span style=''>vertices</span> <span style=''>under</span> <span style=''>some</span> <span style=''>mild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temperature</span> <span style=''>regions</span> <span style=''>where</span> <span style=''>the</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>provably</span> <span style=''>mixes</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784326);'>exponentially</span> <span style=''>slow</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Key</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>of</span> <span style=''>swimmer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordination</span> <span style=''>through</span> <span style=''>Sparse</span> <span style=''>Fisher</span> <span style=''>EM</span> <br/><br/><span style=''>To</span> <span style=''>answer</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>optimal</span> <span style=''>swimmer</span> <span style=''>learningteaching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>this</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>two</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>temporal</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>motor</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>breaststroke</span> <span style=''>swimming</span> <span style=''>Each</span> <span style=''>level</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>through</span> <span style=''>Sparse</span> <span style=''>Fisher</span> <span style=''>EM</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>on</span> <span style=''>large</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>datasets</span> <span style=''>The</span> <span style=''>induced</span> <span style=''>sparsity</span> <span style=''>selects</span> <span style=''>key</span> <span style=''>points</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordination</span> <span style=''>phase</span> <span style=''>without</span> <span style=''>any</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12040014290818149)
# 	experimental (0.13504823151125403)
# 	architecture (0.0811003929974991)
# 	knowledge (0.12754555198285103)
# 	segmentation (0.07609860664523044)
# 	detection (0.12075741336191496)
# 	information (0.2590210789567703)
# 	recognition (0.12575919971418364)
# 	different (0.2679528403001072)
# 	convolutional (0.1400500178635227)
#
# Some Statistics words are:
# 	variational (0.10144927536231885)
# 	theoretical (0.1469265367316342)
# 	variables (0.13493253373313344)
# 	estimation (0.1714142928535732)
# 	algorithm (0.39930034982508744)
# 	statistical (0.15792103948025987)
# 	dimensional (0.1874062968515742)
# 	inference (0.19540229885057472)
# 	distribution (0.19390304847576212)
# 	regression (0.18990504747626186)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9b838c6-2f4f-48b7-9314-7705af5b5be5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9b838c6-2f4f-48b7-9314-7705af5b5be5")) {                    Plotly.newPlot(                        "d9b838c6-2f4f-48b7-9314-7705af5b5be5",                        [{"x":["computational","approximate","uncertainty","inference","parameterization","regression","generative","approximations","complexity","applications","algorithm","posteriori","interested","predictive","posterior","processes","posteriors","variables","principled","structured","variational","dependencies","capturing","structure","heterogeneous","preference","parametric","parameters","combinations","dimension","empirically","observing","potential","consisting","preferences","customers","population","customization","observation","structural","likelihood","underlying","personalized","dimensional","specialized","assortment","offerings","regularized","estimator","observations","assumptions","introducing","representations","existence","literature","parameter","available","establish","autoencoder","disentanglement","extension","interpretable","autoencoders","consistent","consequences","independent","controlling","disentangled","quantifying","performance","enforcing","behaviour","discriminative","predictable","experiments","effectively","generated","represents","sequences","annotated","decomposition","facilitate","challenges","description","recurrently","accomplishing","predicting","hierarchically","recurrent","knowledge","containing","alleviate","according","integrate","prediction","representation","extensively","specified","procedure","effectiveness","auxiliary","introduce","secondary","structures","algorithms","technique","reconstructed","composition","alternative","duplicate","construction","generating","frameworks","decreasing","synthetic","solutions","including","multiplication","experimental","representing","techniques","approaches","particular","information","preserving","distilled","principles","remarkable","protection","qualitative","corresponding","summarizing","difficult","defending","incorporates","estimates","difference","defensive","percentage","quantitative","pertaining","possession","strategies","advantage","trajectory","understanding","reinforcement","comprehensive","identified","framework","observational","combining","unfamiliar","statistician","imputation","estimation","causality","judiciously","estimating","statisticians","estimated","demonstrated","generalized","challenging","incomplete","nonlinear","beginning","debugging","shrinking","elimination","inability","automated","different","implementations","development","outperform","convolutions","exploitation","convolutional","historical","architecture","conditional","processing","autoregressive","correlation","multivariate","forecasting","thermodynamic","presented","quantities","interesting","extensive","throughout","annealing","distribution","stochastic","practically","functions","integrals","simulation","simulated","production","typically","metropolis","probabilistic","minimized","calculation","associated","temperature","comparison","extraction","particles","interpreted","propagates","interfaces","annotation","understand","answering","qualitatively","attention","questions","quantitatively","indicator","corrupted","automatically","substantial","measurements","hierarchical","objective","hyperparameters","improvement","developed","compressed","filtering","conventional","automatic","faithfully","represent","resolution","tomography","optimized","penalized","importantly","radiation","maintaining","clustering","simulations","transform","efficient","transforms","uniformity","overcomplete","augmented","linearized","imp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	assortment
# 	disentanglement
# 	statistician
# 	judiciously
# 	statisticians
# 	thermodynamic
# 	integrals
# 	nonadaptive
# 	connectome
# 	percolation
# 	tractably
# 	permissive
# 	censoring
# 	uhlenbeck
# 	confirming
# 	heteroscedasticity
# 	eigenspaces
# 	spectroscopy
# 	advantageously
# 	expansions
# Some words which never appear in Statistics papers:
# 	recurrently
# 	accomplishing
# 	duplicate
# 	defending
# 	possession
# 	arithmetical
# 	memristor
# 	unexpectedly
# 	concatenating
# 	unnatural
# 	valuation
# 	replacements
# 	motivational
# 	breathing
# 	strategically
# 	propositional
# 	compilation
# 	mammograms
# 	mammogram
# 	contrasting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074652564260239e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
